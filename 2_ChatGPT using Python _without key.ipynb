# %% [markdown]
# OpenAI is a cutting-edge AI research lab that is developing advanced artificial intelligence technologies. ChatGPT is a state-of-the-art language model developed by OpenAI, that is capable of generating human-like text. The ChatGPT API allows developers to access the capabilities of ChatGPT and use it in their own projects, such as in Jupyter Notebooks.
#
# Using the ChatGPT API directly in your Jupyter notebook can be a powerful way to generate human-like text quickly and easily. This guide will walk you through the process of setting up the API and using it to generate text in a Jupyter notebook.
#
# # Step 1: Install the OpenAI library.
# To use the ChatGPT API, you’ll first need to install the OpenAI library. This can be done by running the following command inyour command prompt:

# %%
# !pip install ipython-gpt
# Out:
# Requirement already satisfied: ipython-gpt in c:\users\monika201103\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: ipython<9.0.0,>=8.12.0 in c:\users\monika201103\anaconda3\lib\site-packages (from ipython-gpt) (8.14.0)
# Requirement already satisfied: stack-data in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (0.6.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (2.11.2)
# Requirement already satisfied: decorator in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (5.1.1)
# Requirement already satisfied: colorama in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (0.4.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (3.0.39)
# Requirement already satisfied: typing-extensions in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (4.3.0)
# Requirement already satisfied: matplotlib-inline in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (0.1.6)
# Requirement already satisfied: backcall in c:\users\monika201103\anaconda3\lib\site-packages (from ipython<9.0.0,>=8.12.0->ipython-gpt) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\monika201103\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9.0.0,>=8.12.0->ipython-gpt) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\monika201103\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9.0.0,>=8.12.0->ipython-gpt) (0.2.5)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\monika201103\anaconda3\lib\site-packages (from stack-data->ipython<9.0.0,>=8.12.0->ipython-gpt) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\monika201103\anaconda3\lib\site-packages (from stack-data->ipython<9.0.0,>=8.12.0->ipython-gpt) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\monika201103\anaconda3\lib\site-packages (from stack-data->ipython<9.0.0,>=8.12.0->ipython-gpt) (1.2.0)
# Requirement already satisfied: six in c:\users\monika201103\anaconda3\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython<9.0.0,>=8.12.0->ipython-gpt) (1.16.0)

# %% [markdown]
# # Step 2: Set up an API key.
# You will also need to set up an API key. You can get one from the OpenAI website. Once you have your API key, you can use it to create an API client by running the following code in your Jupyter notebook:

# %% [markdown]
# # https://platform.openai.com/account/api-keys

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\monika201103\anaconda3\lib\site-packages (0.27.8)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.20 in c:\users\monika201103\anaconda3\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: aiohttp in c:\users\monika201103\anaconda3\lib\site-packages (from openai) (3.8.5)
# Requirement already satisfied: tqdm in c:\users\monika201103\anaconda3\lib\site-packages (from openai) (4.64.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\monika201103\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\monika201103\anaconda3\lib\site-packages (from requests>=2.20->openai) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\monika201103\anaconda3\lib\site-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\monika201103\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\monika201103\anaconda3\lib\site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\monika201103\anaconda3\lib\site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\monika201103\anaconda3\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\monika201103\anaconda3\lib\site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\monika201103\anaconda3\lib\site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\monika201103\anaconda3\lib\site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: colorama in c:\users\monika201103\anaconda3\lib\site-packages (from tqdm->openai) (0.4.5)

# %%
import openai
openai.api_key = "OpenAI _API Key"

# %% [markdown]
# # Step 3: Generate text.
# Now that you have set up the API client, you can use it to generate text by running the following code in your Jupyter notebook:

# %%
# Generate text
prompt = "What is the weather like in London today?"
completions = openai.Completion.create(
    engine="text-davinci-002",
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Print the generated text
message = completions.choices[0].text
print(message)
# Out:
# The weather in London is Cloudy with a high of 52 degrees and a low of 41 degrees.

# %% [markdown]
# In this example, we’re using the “text-davinci-002” engine, with a prompt of “What is the weather like in London today?” We’re also specifying that we want the API to generate up to 1024 tokens of text, and that we want it to generate a single response. The stop parameter allows you to specify a sequence of tokens at which the API will stop generating text. The temperature parameter controls the randomness of the output.
#
# You can adjust the prompt, engine, max_tokens, n, stop, and temperature parameters to control the output generated by the API.
#
# In conclusion, using the ChatGPT API in Jupyter Notebook is a powerful way to generate human-like text quickly and easily. With just a few lines of code, you can set up the API, generate text, and use it in your projects or research.

# %%
# %%chat --max-tokens=25
# Out:
# UsageError: Cell magic `%%chat` not found.
