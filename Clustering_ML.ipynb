# %% [markdown]
# ### K-Means Clustering Algorithm
#
# #### K-Means Clustering is an unsupervised learning algorithm that is used to solve the clustering problems in machine learning or data science. In this topic, we will learn what is K-means clustering algorithm, how the algorithm works, along with the Python implementation of k-means clustering.
#
# ### What is K-Means Algorithm?
#
# #### K-Means Clustering is an Unsupervised Learning algorithm, which groups the unlabeled dataset into different clusters. Here K defines the number of pre-defined clusters that need to be created in the process, as if K=2, there will be two clusters, and for K=3, there will be three clusters, and so on.
#
# #### It is an iterative algorithm that divides the unlabeled dataset into k different clusters in such a way that each dataset belongs only one group that has similar properties.
#
# #### It allows us to cluster the data into different groups and a convenient way to discover the categories of groups in the unlabeled dataset on its own without the need for any training.
#
# #### It is a centroid-based algorithm, where each cluster is associated with a centroid. The main aim of this algorithm is to minimize the sum of distances between the data point and their corresponding clusters.
#
#
# #### The algorithm takes the unlabeled dataset as input, divides the dataset into k-number of clusters, and repeats the process until it does not find the best clusters. The value of k should be predetermined in this algorithm.
#
# ### The k-means clustering algorithm mainly performs two tasks:
#
# #### Determines the best value for K center points or centroids by an iterative process.
#
# #### Assigns each data point to its closest k-center. Those data points which are near to the particular k-center, create a cluster.

# %% [markdown]
# ### Hence each cluster has datapoints with some commonalities, and it is away from other clusters.
#
# #### The below diagram explains the working of the K-means Clustering Algorithm:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How does the K-Means Algorithm Work?
#
# #### The working of the K-Means algorithm is explained in the below steps:
#
# Step-1: Select the number K to decide the number of clusters.
#
# Step-2: Select random K points or centroids. (It can be other from the input dataset).
#
# Step-3: Assign each data point to their closest centroid, which will form the predefined K clusters.
#
# Step-4: Calculate the variance and place a new centroid of each cluster.
#
# Step-5: Repeat the third steps, which means reassign each datapoint to the new closest centroid of each cluster.
#
# Step-6: If any reassignment occurs, then go to step-4 else go to FINISH.
#
# Step-7: The model is ready.

# %% [markdown]
# K-Means clustering
#
# K-means is a centroid-based clustering algorithm, where we calculate the distance between each data point and a centroid to assign it to a cluster. The goal is to identify the K number of groups in the dataset.
#
# “K-means clustering is a method of vector quantization, originally from signal processing, that aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean, serving as a prototype of the cluster.” – Source
#
# It is an iterative process of assigning each data point to the groups and slowly data points get clustered based on similar features. The objective is to minimize the sum of distances between the data points and the cluster centroid, to identify the correct group each data point should belong to.
#
# Here, we divide a data space into K clusters and assign a mean value to each. The data points are placed in the clusters closest to the mean value of that cluster. There are several distance metrics available that can be used to calculate the distance.

# %% [markdown]
# ### How does K-means work?
#
# Let’s take an example to understand how K-means work step by step. The algorithm can be broken down into 4-5 steps.
#
# 1. Choosing the number of clusters
# The first step is to define the K number of clusters in which we will group the data. Let’s select K=3.
#
# 2. Initializing centroids
# Centroid is the center of a cluster but initially, the exact center of data points will be unknown so, we select random data points and define them as centroids for each cluster. We will initialize 3 centroids in the dataset.
#
# ![image.png](attachment:image.png)
#
#
#
# 3. Assign data points to the nearest cluster
# Now that centroids are initialized, the next step is to assign data points Xn to their closest cluster centroid Ck
#
# ![image-2.png](attachment:image-2.png)
#
# In this step, we will first calculate the distance between data point X and centroid C using Euclidean Distance metric.
#
# ![image-3.png](attachment:image-3.png)
#
# And then choose the cluster for data points where the distance between the data point and the centroid is minimum.
#
# ![image-4.png](attachment:image-4.png)
#
#
# 4. Re-initialize centroids
# Next, we will re-initialize the centroids by calculating the average of all data points of that cluster.
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
#
# 5. Repeat steps 3 and 4
# We will keep repeating steps 3 and 4 until we have optimal centroids and the assignments of data points to correct clusters are not changing anymore.
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ### The optimal centroids are found and the assignments of data points to the correct clusters no longer change, typically indicate convergence of the algorithm. In KMeans, convergence occurs when the algorithm reaches a stable state, and further iterations don't alter the centroids or the assignments significantly.
#
# ### Here are two common indicators that can suggest convergence in KMeans clustering:
#
# #### 1. Centroid Stability: The centroids of the clusters no longer change significantly between iterations. The algorithm repeatedly updates the centroids based on the mean of the data points assigned to each cluster. When the centroids stabilize and their positions remain nearly unchanged across iterations, it suggests convergence.
#
# #### 2. Data Point Assignments: Data points stop switching clusters or change minimally between iterations. As the algorithm progresses, data points are reassigned to the nearest centroid (cluster). When these assignments remain consistent over subsequent iterations, it indicates that the data points are now relatively well-clustered, and further iterations don’t alter these assignments significantly.
#
# ### To explicitly identify convergence in the KMeans algorithm:
#
# #### You can set a maximum number of iterations (max_iter) in the KMeans function. If the algorithm reaches this limit without significant changes in centroids or assignments, it might be considered converged.
#
# #### Monitor changes in the inertia (or within-cluster sum of squares), which is available via the kmeans.inertia_ attribute in scikit-learn. When the inertia stabilizes or changes very little between iterations, it suggests convergence.
#
# #### Keep in mind that convergence doesn’t guarantee the optimal clustering for a particular dataset. Sometimes, running KMeans multiple times with different initializations (using the n_init parameter) and choosing the best result based on some criterion (like inertia or silhouette score) might yield more stable and reliable clustering results.

# %%
# importing libraries    
import numpy as nm    
import matplotlib.pyplot as mtp    
import pandas as pd

# %%
# Importing the dataset  
dataset = pd.read_csv('C:/Users/Faraz Ahmad/Downloads/Mall_Customers.csv')

# %%
x = dataset.iloc[:, [3, 4]].values

# %%
from sklearn.cluster import KMeans  
import matplotlib.pyplot as plt  # Importing matplotlib with alias plt

wcss_list = []  # Initializing the list for the values of WCSS  
#Initializes an empty list wcss_list that will store the Within-Cluster Sum of Squares (WCSS) values.

# Using for loop for iterations from 1 to 10.  
for i in range(1, 11):  
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)  
    kmeans.fit(x)  
    wcss_list.append(kmeans.inertia_)  #  retrieves the inertia (WCSS) for the fitted KMeans model and appends it to the wcss_list.

plt.plot(range(1, 11), wcss_list)  # Changed mtp to plt for consistency
plt.title('The Elbow Method Graph')  
plt.xlabel('Number of clusters (k)')  
plt.ylabel('WCSS')  # Corrected ylabel to WCSS for clarity
plt.show()
# Out:
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [raw]
# The Within-Cluster Sum of Squares (WCSS), also known as inertia in the context of KMeans clustering, is a measure that quantifies the compactness or homogeneity of clusters created by a clustering algorithm.
#
# In KMeans clustering:
#
# WCSS measures the sum of squared distances between each data point in a cluster and its centroid.
# For each cluster, it computes the sum of the squared distances of each point in the cluster to the centroid of that cluster.
# The total WCSS is the sum of these values across all clusters.
# The goal of KMeans clustering is to minimize the WCSS. A lower WCSS value indicates that the data points within each cluster are closer to their centroid, suggesting more compact and well-separated clusters.
#
# When using the Elbow Method to determine the optimal number of clusters, practitioners plot the number of clusters against the corresponding WCSS values. The "elbow" point in the plot represents a point of diminishing returns where adding more clusters doesn't significantly decrease the WCSS. This point often serves as a heuristic for determining an appropriate number of clusters for the data.
#
# As the number of clusters increases, the WCSS tends to decrease because each cluster tends to have fewer data points, resulting in smaller within-cluster distances. However, beyond a certain point, the rate of decrease in WCSS slows down, leading to an "elbow" in the plot, suggesting an optimal number of clusters for the given dataset.

# %%
#training the K-means model on a dataset  
kmeans = KMeans(n_clusters=5, init='k-means++', random_state= 42)  
y_predict= kmeans.fit_predict(x)
# Out:
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# n_clusters=5: Specifies the number of clusters (in this case, 5) that the algorithm will attempt to identify within the dataset.
#
# init='k-means++': Indicates the method used for initializing the centroids before clustering.
#
# 'k-means++' is a smart initialization technique that aims to place centroids in a way that speeds up the convergence of the algorithm.
#
# random_state=42: Sets the random seed for reproducibility. It ensures that if you run the code multiple times, you'll get the same results as long as the other parameters and data remain unchanged.

# %%
#visulaizing the clusters  
mtp.scatter(x[y_predict == 0, 0], x[y_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
mtp.scatter(x[y_predict == 1, 0], x[y_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
mtp.scatter(x[y_predict== 2, 0], x[y_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
mtp.scatter(x[y_predict == 3, 0], x[y_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
mtp.scatter(x[y_predict == 4, 0], x[y_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster  
mtp.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')   
mtp.title('Clusters of customers')  
mtp.xlabel('Annual Income (k$)')  
mtp.ylabel('Spending Score (1-100)')  
mtp.legend()  
mtp.show()  

#  x[y_predict == 0, 0] selects elements from the first feature (dimension) of the dataset x where the corresponding cluster label in y_predict is equal to 0.
#  x[y_predict == 0, 1] selects elements from the second feature (dimension) of the dataset x where the corresponding cluster label in y_predict is equal to 0.

# %%
kmeans.fit(x)
print("WCSS:", kmeans.inertia_)

#In KMeans clustering, inertia_ attribute provides the sum of squared distances of samples to their closest cluster center. 
#Lower inertia indicates tighter clusters.
# Out:
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# WCSS: 68268.79713978159

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(x, y_predict)
print("Silhouette Score:", silhouette_avg)

#Measures how well-separated clusters are. It ranges from -1 to 1, where higher values indicate better-defined clusters.
# Out:
# Silhouette Score: 0.4497782204673568

# %%
from sklearn.metrics import calinski_harabasz_score
ch_score = calinski_harabasz_score(x, y_predict)
print("Calinski-Harabasz Score:", ch_score)
#Computes the ratio of between-cluster dispersion to within-cluster dispersion. 
#Higher values represent better-defined clusters.
# Out:
# Calinski-Harabasz Score: 478.48790740519104

# %%
from sklearn.metrics import davies_bouldin_score
db_score = davies_bouldin_score(x, y_predict)
print("Davies-Bouldin Score:", db_score)

#Computes the average similarity between each cluster and its most similar one. Lower values indicate better clustering.
# Out:
# Davies-Bouldin Score: 0.7890863394750914

# %% [markdown]
# Remember, the choice of evaluation metric depends on the specific characteristics of your data and the goals of your analysis. It's often recommended to use multiple metrics to comprehensively assess the quality of clustering results.
#
# These metrics can help in determining how well the clusters are formed, how separated they are, and how internally consistent they are. However, interpreting these metrics might vary depending on the nature of the dataset and the problem domain. It's important to consider domain knowledge and the context in which the clustering is applied while interpreting these evaluation scores.

# %%
#KMEans 2nd Example

import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Generate sample data
np.random.seed(42)
# Creating random data with two features
data = np.random.randn(100, 2) * 3 + 2

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Finding the optimal number of clusters using the Elbow Method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Method graph
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='-', color='blue')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.xticks(np.arange(1, 11, 1))
plt.grid(True)
plt.show()

# Choosing the optimal number of clusters (let's say 3) and fitting the final KMeans model
optimal_clusters = 3
final_kmeans = KMeans(n_clusters=optimal_clusters, init='k-means++', random_state=42)
final_kmeans.fit(scaled_data)

# Get cluster labels for each data point
cluster_labels = final_kmeans.labels_

# Plotting the clusters
plt.figure(figsize=(8, 6))
for cluster in range(optimal_clusters):
    plt.scatter(scaled_data[cluster_labels == cluster, 0], scaled_data[cluster_labels == cluster, 1], label=f'Cluster {cluster + 1}')
plt.scatter(final_kmeans.cluster_centers_[:, 0], final_kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids', marker='X')
plt.title('KMeans Clustering with Standardized Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
print("Shape of scaled_data:", scaled_data.shape)
print("Shape of y_predict:", y_predict.shape)
# Out:
# Shape of scaled_data: (100, 2)
# Shape of y_predict: (250,)

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Generating sample data
np.random.seed(42)
data = np.random.randn(100, 2) * 3 + 2  # Generating random data with two features

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Performing KMeans clustering
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)
y_predict = kmeans.fit_predict(scaled_data)

# Calculating evaluation metrics
inertia = kmeans.inertia_
silhouette_avg = silhouette_score(scaled_data, y_predict)
ch_score = calinski_harabasz_score(scaled_data, y_predict)
db_score = davies_bouldin_score(scaled_data, y_predict)

# Displaying the evaluation metrics
print("WCSS (Inertia):", inertia)
print("Silhouette Score:", silhouette_avg)
print("Calinski-Harabasz Score:", ch_score)
print("Davies-Bouldin Score:", db_score)
# Out:
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# WCSS (Inertia): 80.97157524383526
# Silhouette Score: 0.3658276437359579
# Calinski-Harabasz Score: 71.29512527439074
# Davies-Bouldin Score: 0.8667082323076681

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
import matplotlib.pyplot as plt

# Generating sample data
np.random.seed(42)
data = np.random.randn(100, 2) * 3 + 2  # Generating random data with two features

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Finding the optimal number of clusters using the Elbow Method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Method graph
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='-', color='blue')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.xticks(np.arange(1, 11, 1))
plt.grid(True)
plt.show()

# Performing KMeans clustering
optimal_clusters = 3  # Choose the optimal number of clusters
final_kmeans = KMeans(n_clusters=optimal_clusters, init='k-means++', random_state=42)
final_kmeans.fit(scaled_data)

# Get cluster labels for each data point
cluster_labels = final_kmeans.labels_

# Calculating evaluation metrics
inertia = final_kmeans.inertia_
silhouette_avg = silhouette_score(scaled_data, cluster_labels)
ch_score = calinski_harabasz_score(scaled_data, cluster_labels)
db_score = davies_bouldin_score(scaled_data, cluster_labels)

# Displaying the evaluation metrics
print("WCSS (Inertia):", inertia)
print("Silhouette Score:", silhouette_avg)
print("Calinski-Harabasz Score:", ch_score)
print("Davies-Bouldin Score:", db_score)
# Out:
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Faraz Ahmad\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# Here's an interpretation of the results obtained from the KMeans clustering evaluation metrics:
#
# WCSS (Inertia): 80.97157524383526
#
# Interpretation: Within-Cluster Sum of Squares (WCSS) or inertia measures the sum of squared distances of samples to their assigned cluster centroids.
# Interpretation of Value: A lower WCSS indicates that the data points within each cluster are closer to the centroid, suggesting more compact and well-separated clusters. In this case, the value 80.97 suggests relatively tight clusters.
# Silhouette Score: 0.3658276437359579
#
# Interpretation: Silhouette Score measures how well-separated clusters are. It quantifies the average distance between clusters and the separation of clusters.
# Interpretation of Value: The silhouette score ranges between -1 to 1, where higher values indicate better-defined clusters. Here, the score of 0.366 suggests moderate separation and reasonable clustering structure.
# Calinski-Harabasz Score: 71.29512527439074
#
# Interpretation: The Calinski-Harabasz Index calculates the ratio of between-cluster dispersion to within-cluster dispersion. It evaluates how well-separated the clusters are.
# Interpretation of Value: A higher Calinski-Harabasz score implies better-defined, more separated clusters. The value of 71.30 indicates a reasonable cluster separation.
# Davies-Bouldin Score: 0.8667082323076681
#
# Interpretation: The Davies-Bouldin Index computes the average similarity between each cluster and its most similar one. It assesses the compactness and separability of clusters.
# Interpretation of Value: The index ranges from 0 to infinity; lower values denote better clustering. Here, the score of 0.867 suggests moderate overlap or similarity between clusters, but still indicates reasonable clustering structure.
# Overall Interpretation:
#
# The WCSS shows relatively compact clusters.
# Silhouette score, Calinski-Harabasz Index, and Davies-Bouldin Index collectively indicate moderate but reasonably defined clusters with some degree of overlap or similarity between clusters.
# These metrics provide a comprehensive evaluation of the clustering quality, suggesting a moderately well-structured clustering pattern in the data. Adjusting the number of clusters or exploring different clustering algorithms might further refine the clustering results.
